# %% [markdown]
# array_pixels_training.npy

# %%
import numpy as np
import pandas as pd
np.random.seed(1)
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img_array = np.load('array_pixels_training.npy')

# %%
plt.imshow(img_array[0])
