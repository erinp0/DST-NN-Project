# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
training_data = np.load('array_pixels_training.npy')
training_label = np.load('array_pixels_label.npy')

# %%
orig_data = np.load('unedited_train_data.npy')
orig_label = np.load('unedited_train_labels.npy')

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(Flatten())
model.add(Dense(43, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(training_data, training_label, epochs=1, batch_size=32)
# Out:
# 2984/2984 [==============================] - 43s 14ms/step - loss: 3.7636 - accuracy: 0.0221

# %%
print(training_label.shape)
# Out:
# (95460,)

# %%
print(orig_label.shape)
# Out:
# (95460,)

# %%
print(training_label[:10])
# Out:
# [30  5  2  5 20 32  4  9  2  0]

# %%
print(orig_label[:10])
# Out:
# [30  5  2  5 20 32  4  9  2  0]

# %%
print(training_data.shape)
# Out:
# (95460, 32, 32, 3)

# %%
print(orig_data.shape)
# Out:
# (95460, 32, 32, 3)

# %%
plt.figure(figsize=(25,25))

for i in range(1,26):
    plt.subplot(5,5,i)
    plt.imshow(training_data[i-1])

# %%
plt.figure(figsize=(25,25))

for i in range(1,26):
    plt.subplot(5,5,i)
    plt.imshow(orig_data[i-1])

# %%
print(training_label[:25])
# Out:
# [30  5  2  5 20 32  4  9  2  0 35 40 11 13 21 21 27 10 21 21 25  8 12  2
#  15]

# %%
train_labels=data = np.genfromtxt('train.csv', delimiter=',', skip_header=1, dtype=int)

# %%
print(train_labels[:25])
# Out:
# [20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#  20]

# %%
print(train_labels.shape)
# Out:
# (39209,)

# %%
orig_data = np.load('32_original_train_data.npy')
orig_label = np.load('32_original_train_labels.npy')

# %%
print(orig_data.shape)
# Out:
# (39209, 32, 32, 3)

# %%
print(orig_label.shape)
# Out:
# (39209,)

# %%
print(orig_label[:25])
# Out:
# [26 15 13 10 15 12 25  2 11 35  2  9 13 26  1 31  2  5 24 10 11 10 11 34
#   5]

# %%
plt.figure(figsize=(25,25))

for i in range(1,26):
    plt.subplot(5,5,i)
    plt.imshow(orig_data[i-1])

# %%
labels2 = np.load('32_filter_training_labels.npy')

# %%
print(labels2[:25])
# Out:
# [30  5  2  5 20 32  4  9  2  0 35 40 11 13 21 21 27 10 21 21 25  8 12  2
#  15]

# %%
labels2.shape
# Out:
# (95460,)
