# %% [markdown]
# # Autoencoder

# %% [markdown]
# ## Build Autoencoder

# %%
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import platform

# %%
print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-13.0-arm64-arm-64bit
# Tensor Flow Version: 2.12.0
# Keras Version: 2.12.0
#
# Python 3.10.10 | packaged by conda-forge | (main, Mar 24 2023, 20:12:31) [Clang 14.0.6 ]
# Pandas 1.5.3
# Scikit-Learn 1.2.2
# GPU is available

# %%
# Load the original training data 
import numpy as np
original_train = np.load('/Users/xinyu/Downloads/32_filter_training_data.npy')

# %%
print(original_train)
# Out:
# [[[[0.16470589 0.23137255 0.41568628]
#    [0.15294118 0.21176471 0.3764706 ]
#    [0.13725491 0.2        0.30588236]
#    ...
#    [0.16470589 0.31764707 0.53725493]
#    [0.19215687 0.33333334 0.53333336]
#    [0.26666668 0.43921569 0.6901961 ]]
#
#   [[0.18431373 0.25882354 0.41568628]
#    [0.16078432 0.22745098 0.35686275]
#    [0.1254902  0.20784314 0.34509805]
#    ...
#    [0.09019608 0.21960784 0.36470589]
#    [0.07450981 0.19215687 0.23921569]
#    [0.11764706 0.26666668 0.32941177]]
#
#   [[0.1882353  0.27843139 0.44705883]
#    [0.14509805 0.24705882 0.37254903]
#    [0.10980392 0.22745098 0.38039216]
#    ...
#    [0.10588235 0.22352941 0.34509805]
#    [0.07058824 0.19215687 0.23921569]
#    [0.07843138 0.21176471 0.26274511]]
#
#   ...
#
#   [[0.12156863 0.2        0.36862746]
#    [0.14901961 0.21568628 0.35686275]
#    [0.12156863 0.18039216 0.31764707]
#    ...
#    [0.12941177 0.25882354 0.36078432]
#    [0.16078432 0.26274511 0.39215687]
#    [0.15686275 0.27450982 0.3882353 ]]
#
#   [[0.16862746 0.23921569 0.38431373]
#    [0.16862746 0.23137255 0.39215687]
#    [0.2        0.25098041 0.41960785]
#    ...
#    [0.17254902 0.29411766 0.40784314]
#    [0.22352941 0.32156864 0.4627451 ]
#    [0.16862746 0.27450982 0.40392157]]
#
#   [[0.20392157 0.30588236 0.45490196]
#    [0.19215687 0.29019609 0.48235294]
#    [0.21176471 0.30588236 0.48235294]
#    ...
#    [0.18431373 0.32156864 0.43529412]
#    [0.12941177 0.23921569 0.33333334]
#    [0.12156863 0.22352941 0.31764707]]]
#
#
#  [[[0.8643503  0.85179559 0.78802201]
#    [0.9748177  0.97420542 0.98805758]
#    [0.9748177  0.97420542 1.        ]
#    ...
#    [0.28215722 0.27557372 0.30435391]
#    [0.27618601 0.26661691 0.2983827 ]
#    [0.27917161 0.26960251 0.2983827 ]]
#
#   [[0.84643666 0.83686756 0.80295003]
#    [0.9748177  0.97420542 0.99402879]
#    [0.9748177  0.97420542 1.        ]
#    ...
#    [0.2732004  0.26661691 0.2983827 ]
#    [0.2732004  0.26661691 0.29539709]
#    [0.28215722 0.26661691 0.29539709]]
#
#   [[0.83150863 0.82193954 0.80295003]
#    [0.9748177  0.97420542 1.        ]
#    [0.1882353  0.21176471 0.21176471]]
#
#   [[0.22352941 0.28627452 0.32549021]
#    [0.23529412 0.28235295 0.30588236]
#    [0.22352941 0.24313726 0.25882354]
#    ...
#    [0.18039216 0.19215687 0.19607843]
#    [0.1882353  0.2        0.19607843]
#    [0.1882353  0.21176471 0.21176471]]]
#
#
#  [[[0.47581653 0.54092401 0.68626222]
#    [0.48721183 0.54852087 0.70145594]
#    [0.49860712 0.5637146  0.72804496]
#    ...
#    [0.98860471 0.93975926 0.98253983]
#    [1.         0.96254985 0.99393512]
#    [0.98480628 0.95875141 0.99013669]]
#
#   [[0.4720181  0.54092401 0.68626222]
#    [0.48721183 0.55991617 0.7090528 ]
#    [0.48721183 0.5637146  0.71664967]
#    ...
#    [0.97341098 0.92836397 0.99013669]
#    [0.98860471 0.95115455 0.99393512]
#    [0.97341098 0.94735612 0.99013669]]
#
#   [[0.49860712 0.5637146  0.7090528 ]
#    [0.50620398 0.56751303 0.71664967]
#    [0.47961496 0.54092401 0.69006065]
#    ...
#    [0.90503923 0.88658123 0.95595081]
#    [0.93542667 0.91696867 0.97114454]
#    [0.95441883 0.9321624  0.99013669]]
#
#   ...
#
#   [[0.44163065 0.45735853 0.55711557]
#    [0.4226385  0.44216481 0.54572027]
#    [0.4226385  0.44216481 0.5495187 ]
#    ...
#    [0.43403379 0.44596324 0.54192184]
#    [0.40744478 0.41937422 0.46975166]
#    [0.36566204 0.37379305 0.44696107]]
#
#   [[0.43403379 0.4535601  0.55331714]
#    [0.41504164 0.43456795 0.53812341]
#    [0.40744478 0.43076952 0.53812341]
#    ...
#    [0.47581653 0.49914127 0.57990615]
#    [0.44542909 0.46115696 0.50393753]
#    [0.39225105 0.39658364 0.46215479]]
#
#   [[0.43023536 0.44216481 0.54192184]
#    [0.41124321 0.42317265 0.52672812]
#    [0.40744478 0.42697109 0.53432498]
#    ...
#    [0.44922752 0.46495539 0.53432498]
#    [0.45302595 0.46115696 0.5001391 ]
#    [0.41884007 0.41557579 0.47355009]]]]

# %%
print(original_train.shape)
# Out:
# (39209, 32, 32, 3)

# %%
max_value = np.max(original_train)
min_value = np.min(original_train)
print("Maximum pixel value:", max_value)
print("Minimum pixel value:", min_value)
# Out:
# Maximum pixel value: 1.0
# Minimum pixel value: 0.0

# %%
num_images = 5
images = original_train[:num_images]

# Display the images
fig, axs = plt.subplots(1, num_images, figsize=(10, 10))
for i in range(num_images):
    axs[i].imshow(images[i])
    axs[i].axis('off')
plt.show()

# %%
# Load the data with noise added
noisy_train = np.load('/Users/xinyu/Downloads/noisy_training (1).npy')

# %%
print(noisy_train)
# Out:
# [[[[0.11738464 0.21682313 0.47036512]
#    [0.17213643 0.17029966 0.41714711]
#    [0.14496471 0.15895694 0.26941353]
#    ...
#    [0.12211153 0.29303627 0.51752302]
#    [0.21823347 0.35052474 0.50900094]
#    [0.21635036 0.45870752 0.72255326]]
#    [0.29582937 0.26650163 0.27175719]
#    ...
#    [0.48664747 0.4757429  0.61208776]
#    [0.46963809 0.60185902 0.56984854]
#    [0.55803534 0.55845068 0.67129102]]]
#
#
#  [[[0.45912743 0.46780302 0.39898467]
#    [0.7689146  0.80978259 0.58422591]
#    [0.4038499  0.59139324 0.34037028]
#    ...
#    [0.         0.02426318 0.26214081]
#    [0.34208272 0.18254407 0.1616556 ]
#    [0.23515867 0.20973192 0.15790826]]
#
#   [[0.26737222 0.25608453 0.30979528]
#    [0.73965048 0.55849674 0.27002062]
#    [0.54943963 0.62180841 0.65704568]
#    ...
#    [0.11720915 0.01711962 0.15440155]
#    [0.22095299 0.22001384 0.30479334]
#    [0.10029659 0.05990965 0.15016107]]
#
#   [[0.42905532 0.48895725 0.55192175]
#    [0.65127509 0.66679512 0.57018049]
#    [0.62211046 0.56286586 0.50032749]
#    ...
#    [0.21122455 0.09129055 0.24542787]
#    [0.08319149 0.26970623 0.08879402]
#    [0.21052941 0.18745719 0.07655415]]
#
#   ...
#
#   [[0.         0.05589898 0.11369745]
#    [0.07315523 0.14904324 0.09793087]
#    [0.0761302  0.15502733 0.        ]
#    ...
#    [0.10775475 0.20060783 0.21331753]
#    [0.18201921 0.09926676 0.22144038]
#    [0.16991649 0.08880974 0.23324017]]
#
#   [[0.         0.10451856 0.22486124]
#    [0.12466945 0.30075318 0.33634982]
#    [0.14336691 0.07933215 0.16301357]
#    ...
#    [0.09842236 0.2523387  0.29674994]
#    [0.2550008  0.06253983 0.31446604]
#    [0.13698175 0.25886303 0.23298638]]
#
#   [[0.         0.1456089  0.13592413]
#    [0.07605948 0.08568482 0.25967441]
#    [0.12727545 0.10609808 0.12122146]
#    ...
#    [0.14717149 0.         0.09250353]
#    [0.12790019 0.18400951 0.12810271]
#    [0.25147957 0.         0.11812334]]]
#
#
#  ...
#
#
#  [[[0.37271871 0.27779888 0.26349694]
#    [0.12508253 0.1250491  0.07514125]
#    [0.17807327 0.12168506 0.15937895]
#    ...
#    [0.02176165 0.08888965 0.0242851 ]
#    [0.01342127 0.08074153 0.08095865]
#    [0.17358495 0.1119822  0.05437021]]
#
#   [[0.35522417 0.28158812 0.29628512]
#    [0.11718552 0.15775517 0.22859831]
#    [0.1854847  0.12212692 0.20592727]
#    ...
#    [0.0848123  0.09850555 0.        ]
#    [0.07154829 0.09033186 0.06144843]
#    [0.08661716 0.10216982 0.13581394]]
#
#   [[0.71298298 0.66007827 0.53495281]
#    [0.28232686 0.26578903 0.31068569]
#    [0.05504144 0.10881032 0.03297195]
#    ...
#    [0.06718313 0.03535759 0.0528463 ]
#    [0.01434036 0.11365048 0.02778548]
#    [0.07993566 0.         0.11300051]]
#
#   ...
#
#   [[0.1273224  0.2257687  0.14149362]
#    [0.10968025 0.23148885 0.19265437]
#    [0.17122847 0.26287188 0.24644532]
#    ...
#    [0.97811847 0.96971092 0.96790952]]
#
#   [[0.49798758 0.57073029 0.70587741]
#    [0.5279191  0.5782598  0.71356446]
#    [0.49124924 0.54702531 0.70536998]
#    ...
#    [0.89485019 0.90963892 0.93654877]
#    [0.92384327 0.89568247 0.97390556]
#    [0.95590727 0.93353971 0.92646518]]
#
#   ...
#
#   [[0.47445151 0.44132208 0.51990766]
#    [0.41031389 0.44843123 0.54643556]
#    [0.41437178 0.44161083 0.58787817]
#    ...
#    [0.43405001 0.45594823 0.549685  ]
#    [0.41900752 0.45343076 0.51052417]
#    [0.37160905 0.38793157 0.45474864]]
#
#   [[0.43993966 0.45023709 0.56354815]
#    [0.4161875  0.43593532 0.53442793]
#    [0.40363664 0.42815577 0.52782273]
#    ...
#    [0.46666938 0.48986204 0.56326225]
#    [0.43735263 0.45473691 0.50108581]
#    [0.36627506 0.4074638  0.46470593]]
#
#   [[0.45185777 0.4709089  0.5583664 ]
#    [0.4106882  0.39063601 0.52234656]
#    [0.42022081 0.39068068 0.54928073]
#    ...
#    [0.47519821 0.44511391 0.53125996]
#    [0.49738842 0.44114231 0.50907929]
#    [0.39813882 0.41970307 0.48546971]]]]

# %%
# Find the range of pixel values in the image data
max_value = np.max(noisy_train)
min_value = np.min(noisy_train)
print("Maximum pixel value:", max_value)
print("Minimum pixel value:", min_value)
# Out:
# Maximum pixel value: 1.0
# Minimum pixel value: 0.0

# %%
# Calculate the mean and standard deviation of the pixel values
pixel_mean = np.mean(noisy_train)
pixel_std = np.std(noisy_train)

print("Pixel mean:", pixel_mean)
print("Pixel standard deviation:", pixel_std)
# Out:
# Pixel mean: 0.47371368815656695
# Pixel standard deviation: 0.2374526743147402

# %%
# Get the shape of the data
print(noisy_train.shape)
# Out:
# (39209, 32, 32, 3)

# %%
num_images = 5
images = noisy_train[:num_images]

# Display the images
fig, axs = plt.subplots(1, num_images, figsize=(10, 10))
for i in range(num_images):
    axs[i].imshow(images[i])
    axs[i].axis('off')
plt.show()

# %%
# Split the noisy data into training and testing sets

n_original = original_train.shape[0]
n_train = int(n_original * 0.9)
n_test = n_original - n_train

x_train_noisy = noisy_train[:n_train]
x_train_original = original_train[:n_train]
x_test_noisy = noisy_train[n_train:]
x_test_original = original_train[n_train:]

# %%
print(n_original)
print(n_train)
print(n_test)
# Out:
# 39209
# 35288
# 3921

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Encoder
input_shape = (32, 32, 3)
input_img = Input(shape=input_shape)
x = Conv2D(48, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(96, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(192, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
encoded = Conv2D(32, (1, 1), activation='relu', padding='same')(x)

# %%
# LATENT SPACE
latentSize = (4,4,32)

# %%
# Decoder
direct_input = Input(shape=latentSize)
x = Conv2D(192, (1, 1), activation='relu', padding='same')(direct_input)
x = UpSampling2D((2, 2))(x)
x = Conv2D(192, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(96, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(48, (3, 3), activation='relu', padding='same')(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

# %%
# Define the model
encoder = Model(input_img, encoded)
decoder = Model(direct_input, decoded)
autoencoder = Model(input_img, decoder(encoded))

autoencoder.summary()
# Out:
# Model: "model_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_34 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_135 (Conv2D)         (None, 32, 32, 48)        1344
#
#  max_pooling2d_47 (MaxPoolin  (None, 16, 16, 48)       0
#  g2D)
#
#  conv2d_136 (Conv2D)         (None, 16, 16, 96)        41568
#
#  max_pooling2d_48 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_137 (Conv2D)         (None, 8, 8, 192)         166080
#
#  max_pooling2d_49 (MaxPoolin  (None, 4, 4, 192)        0
#  g2D)
#
#  conv2d_138 (Conv2D)         (None, 4, 4, 32)          6176
#
#  model_38 (Functional)       (None, 32, 32, 3)         547107
#
# =================================================================
# Total params: 762,275
# Trainable params: 762,275
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
autoencoder.compile(optimizer='Adam', loss='binary_crossentropy')

# %% [markdown]
# ## Train Autoencoder

# %%
# save the trained model
loaded_autoencoder = tf.keras.models.load_model('/Users/xinyu/Downloads/denoising_autoencoder.h5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### 1. View Reconstruction

# %%
# Testing original images
num_images = 5
images = x_test_original[:num_images]

# Display the images
fig, axs = plt.subplots(1, num_images, figsize=(10, 10))
for i in range(num_images):
    axs[i].imshow(images[i])
    axs[i].axis('off')
plt.show()

# %%
# Testing noisy images
num_images = 5
images = x_test_noisy[:num_images]

# Display the images
fig, axs = plt.subplots(1, num_images, figsize=(10, 10))
for i in range(num_images):
    axs[i].imshow(images[i])
    axs[i].axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %%
"""
# Load the trained denoising autoencoder model
loaded_autoencoder = tf.keras.models.load_model('denoising_autoencoder.h5')
"""
# Out:
# "\n# Load the trained denoising autoencoder model\nloaded_autoencoder = tf.keras.models.load_model('denoising_autoencoder.h5')\n"

# %%
# Use the denoising autoencoder to reconstruct the testing data
test_reconstructed = loaded_autoencoder.predict(x_test_noisy)
# Out:
# 123/123 [==============================] - 4s 29ms/step

# %%
# Visualize the original testing data and the reconstructed data
n = 5  # Number of images to visualize
plt.figure(figsize=(20, 4))
for i in range(n):
    # Noisy images
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_noisy[i])
    plt.title('Noisy')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # Reconstructed images
    ax = plt.subplot(3, n, i + n + 1)
    plt.imshow(test_reconstructed[i])
    plt.title('Dinoised')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
 # Original images for comparison
n = 5 
plt.figure(figsize=(20, 4))
for i in range(n):  
    ax = plt.subplot(3, n, i + n + 1)
    plt.imshow(x_test_original[i])
    plt.title('Original')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ### 2. Metrics

# %% [markdown]
# We also measure the reconstruction error between the original testing data and the output of the Denoising autoencoder. This method used mean squared error (MSE), and the lower the reconstruction loss, the better the DAE is at denoising the input.

# %%
mse_loss = np.mean(np.square(x_test_original - test_reconstructed))
print("MSE loss:", mse_loss)
# Out:
# MSE loss: 0.002215753730383356

# %% [markdown]
# Structural Similarity Index (SSIM): SSIM measures the similarity between the original input and the reconstructed output based on three factors: luminance, contrast, and structure. A higher SSIM indicates better performance.

# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: networkx>=2.8 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (2023.3.21)
# Requirement already satisfied: pillow>=9.0.1 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: numpy>=1.21.1 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (1.23.5)
# Requirement already satisfied: PyWavelets>=1.1.1 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: scipy>=1.8 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: imageio>=2.4.1 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (2.27.0)
# Requirement already satisfied: lazy_loader>=0.1 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (0.2)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/tensorflow/lib/python3.10/site-packages (from scikit-image) (23.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Save The Denoised Images

# %% [markdown]
# 1. Noisy_train

# %%
# Use the trained model to denoise the original data (input)
noisy_train_denoised = loaded_autoencoder.predict(noisy_train)
# Out:
# 1226/1226 [==============================] - 32s 26ms/step

# %%
# Visualize the original data and the denoised data
n = 5  # Number of images to visualize
plt.figure(figsize=(20, 4))
for i in range(n):
    
    # Noisy images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(noisy_train[i])
    plt.title('Noisy')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # Reconstructed images
    ax = plt.subplot(2, n, i + n + 1)
    plt.imshow(original_train_denoised[i])
    plt.title('Dinoised')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %%
mse_loss = np.mean(np.square(noisy_train - noisy_train_denoised ))
print("MSE loss:", mse_loss)
# Out:
# MSE loss: 0.00526734703955385

# %%
# Save the denoised output to a NumPy array file
np.save("noisy_train_denoised",noisy_train_denoised)

# %% [markdown]
# 2. 32_filter_training

# %%
 filter = np.load('/Users/xinyu/Downloads/32_filter_training_data.npy')

# %%
filter_denoised = loaded_autoencoder.predict(filter)
# Out:
# 1226/1226 [==============================] - 33s 27ms/step

# %%
mse_loss = np.mean(np.square(filter - filter_denoised ))
print("MSE loss:", mse_loss)
# Out:
# MSE loss: 0.001927958727474747

# %%
np.save("filter_denoised ",filter_denoised )

# %% [markdown]
# 3. black_patched

# %%
black_patched = np.load('/Users/xinyu/Downloads/black_patched_training.npy')

# %%
black_patched_denoised = loaded_autoencoder.predict(black_patched)
# Out:
# 1226/1226 [==============================] - 32s 26ms/step

# %%
mse_loss = np.mean(np.square(black_patched - black_patched_denoised))
print("MSE loss:", mse_loss)
# Out:
# MSE loss: 0.005239987417582013

# %%
np.save("black_patched_denoised",black_patched_denoised)

# %% [markdown]
# 4. white_patched

# %%
white_patched = np.load('/Users/xinyu/Downloads/white_patched_training.npy')

# %%
white_patched_denoised = loaded_autoencoder.predict(white_patched)
# Out:
# 1226/1226 [==============================] - 32s 26ms/step

# %%
n = 5  # Number of images to visualize
plt.figure(figsize=(20, 4))
for i in range(n):
    
    # Noisy images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(white_patched[i])
    plt.title('Noisy')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # Reconstructed images
    ax = plt.subplot(2, n, i + n + 1)
    plt.imshow(white_patched_denoised[i])
    plt.title('Dinoised')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %%
mse_loss = np.mean(np.square(white_patched - white_patched_denoised))
print("MSE loss:", mse_loss)
# Out:
# MSE loss: 0.0040068648754836315

# %%
np.save("white_patched_denoised",white_patched_denoised)

# %% [markdown]
# 5. same_image_patched

# %%
same_image_patched = np.load('/Users/xinyu/Downloads/same_image_patched_training.npy')

# %%
same_image_patched_denoised = loaded_autoencoder.predict(same_image_patched)
# Out:
# 1226/1226 [==============================] - 32s 26ms/step

# %%
mse_loss = np.mean(np.square(same_image_patched - same_image_patched_denoised))
print("MSE loss:", mse_loss)
# Out:
# MSE loss: 0.0028228277589840848

# %%
np.save("same_image_patched_denoised",same_image_patched_denoised)
